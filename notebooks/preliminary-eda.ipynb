# %% [markdown]
# # Capstone I Preliminary EDA
# 7/15/2020

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams.update({'font.size': 16})
plt.style.use('bmh')

# %%
df = pd.read_csv('../data/raw/EdStatsData.csv')

# %%
df.shape
# Out:
# (886930, 70)

# %%
# df.head(10)
print(df.head(5).to_markdown())
# Out:
# |    | Country Name   | Country Code   | Indicator Name                                                          | Indicator Code   |     1970 |     1971 |     1972 |     1973 |     1974 |     1975 |   1976 |     1977 |     1978 |     1979 |     1980 |     1981 |     1982 |     1983 |     1984 |     1985 |     1986 |     1987 |     1988 |     1989 |     1990 |     1991 |     1992 |     1993 |     1994 |     1995 |     1996 |     1997 |     1998 |     1999 |     2000 |     2001 |     2002 |     2003 |     2004 |     2005 |     2006 |     2007 |     2008 |    2009 |    2010 |     2011 |     2012 |     2013 |     2014 |   2015 |   2016 |   2017 |   2020 |   2025 |   2030 |   2035 |   2040 |   2045 |   2050 |   2055 |   2060 |   2065 |   2070 |   2075 |   2080 |   2085 |   2090 |   2095 |   2100 |   Unnamed: 69 |
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
df['Country Code'].nunique()
# Out:
# 242

# %%
usa = df[df['Country Code'] == 'USA']
usa
# Out:
#          Country Name Country Code  \
# 846615  United States          USA
# 846616  United States          USA
# 846617  United States          USA
# 846618  United States          USA
# 846619  United States          USA
# ...               ...          ...
# 850275  United States          USA
# 850276  United States          USA
# 850277  United States          USA
# 850278  United States          USA
# 850279  United States          USA
#
#                                            Indicator Name  \
# 846615  Adjusted net enrolment rate, lower secondary, ...
# 846616  Adjusted net enrolment rate, lower secondary, ...
# 846617  Adjusted net enrolment rate, lower secondary, ...
# 846618  Adjusted net enrolment rate, lower secondary, ...
# 846619  Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 850275  Youth illiterate population, 15-24 years, male...
# 850276  Youth literacy rate, population 15-24 years, b...
# ...

# %%
usa['sum'] = usa.sum(axis=1)
df_to_clean = usa[usa['sum'] != 0]

cols_to_drop = ['Unnamed: 69', '2016', '2017']
for year in range(1970, 1978):
    cols_to_drop.append(str(year))
for year in range(2020, 2101, 5):
    cols_to_drop.append(str(year))

df_cleaned = df_to_clean.drop(columns=cols_to_drop)
usa_clean = df_cleaned.drop(columns='sum')
# Out:
# /home/soultrain/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
usa_per_gdp = usa_clean[usa_clean['Indicator Code'] == 'SE.XPD.TOTL.GD.ZS'].dropna(axis=1)
usa_per_gdp = usa_per_gdp.drop(['Country Name', 'Indicator Name'], axis=1).set_index('Country Code')

print(usa_per_gdp.head(10).to_markdown())
# Out:
# | Country Code   | Indicator Code    |    1986 |    1988 |   1989 |    1990 |    1991 |    1994 |    1995 |    1998 |    1999 |    2001 |    2002 |    2003 |    2004 |    2005 |    2006 |    2007 |    2008 |    2009 |    2010 |   2011 |    2012 |    2013 |    2014 |
# |:---------------|:------------------|--------:|--------:|-------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|-------:|--------:|--------:|--------:|
# | USA            | SE.XPD.TOTL.GD.ZS | 4.58326 | 4.67762 | 4.7985 | 4.81445 | 4.89873 | 4.87318 | 4.94068 | 4.81499 | 4.84966 | 5.44979 | 5.41733 | 5.55414 | 5.31416 | 5.06331 | 5.38623 | 5.22984 | 5.29536 | 5.25622 | 5.42707 | 5.2115 | 5.20087 | 4.93013 | 5.38078 |

# %%
y = usa_per_gdp.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], axis=1).dropna(axis=1)
years = list(b[::-1])
y = y.values.flatten()

# %%
fig, ax = plt.subplots(figsize=(8, 6), dpi=72)

ax.plot(b, color='m', alpha=0.5, label='USA')
ax.set_xlabel('Year')
ax.set_ylabel('% of GDP')
ax.set_xticklabels(years_b, rotation=80)
ax.set_title('Education spending, % of US GDP')
plt.tight_layout()
# plt.savefig('../images/usa-spend-gdp.png')
plt.show()

# %%
df2 = pd.read_csv('../data/raw/EdStatsData.csv')

# %%
swe = df2[df2['Country Code'] == 'SWE']
swe
# Out:
#        Country Name Country Code  \
# 776980       Sweden          SWE
# 776981       Sweden          SWE
# 776982       Sweden          SWE
# 776983       Sweden          SWE
# 776984       Sweden          SWE
# ...             ...          ...
# 780640       Sweden          SWE
# 780641       Sweden          SWE
# 780642       Sweden          SWE
# 780643       Sweden          SWE
# 780644       Sweden          SWE
#
#                                            Indicator Name  \
# 776980  Adjusted net enrolment rate, lower secondary, ...
# 776981  Adjusted net enrolment rate, lower secondary, ...
# 776982  Adjusted net enrolment rate, lower secondary, ...
# 776983  Adjusted net enrolment rate, lower secondary, ...
# 776984  Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 780640  Youth illiterate population, 15-24 years, male...
# 780641  Youth literacy rate, population 15-24 years, b...
# ...

# %%
swe['sum'] = swe.sum(axis=1)
df_to_clean = swe[swe['sum'] != 0]

cols_to_drop = ['Unnamed: 69', '2016', '2017']
for year in range(1970, 1978):
    cols_to_drop.append(str(year))
for year in range(2020, 2101, 5):
    cols_to_drop.append(str(year))

df_cleaned = df_to_clean.drop(columns=cols_to_drop)
swe_clean = df_cleaned.drop(columns='sum')
# Out:
# /home/soultrain/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
swe_per_gdp = swe_clean[swe_clean['Indicator Code'] == 'SE.XPD.TOTL.GD.ZS'].dropna(axis=1)
swe_per_gdp
# Out:
#        Country Name Country Code  \
# 778240       Sweden          SWE
#
#                                            Indicator Name     Indicator Code  \
# 778240  Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
#
#            1979     1980    1981     1990     1991    1992  ...     2005  \
# 778240  6.46725  6.62433  6.8726  5.26878  5.51431  5.3175  ...  6.55354
#
#            2006     2007    2008     2009     2010     2011     2012     2013  \
# 778240  6.40877  6.20952  6.3862  6.85468  6.62198  6.48505  7.66617  7.71755
#
#            2014
# 778240  7.67509
#
# [1 rows x 30 columns]

# %%
b = swe_per_gdp.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], axis=1).dropna(axis=1)
years_b = list(b[::-1])
b = b.values.flatten()

# %%
fig, ax = plt.subplots(figsize=(8, 6), dpi=72)

ax.plot(b, color='m', alpha=0.5, label='Sweden')
ax.set_xlabel('Year')
ax.set_ylabel('% of GDP')
ax.set_xticklabels(years_b, rotation=80)
ax.set_title('Education spending, % of Swedish GDP')
plt.tight_layout()
plt.savefig('../images/swe-spend-gdp.png')
plt.show()

# %%
final_df = pd.read_csv('../data/processed/EdStatsAggregated.csv')

# %%
final_df.head(10)
# Out:
#    Unnamed: 0   Country Name Country Code  \
# 0           0  United States          USA
# 1           1  United States          USA
# 2           2  United States          USA
# 3           3  United States          USA
# 4           4  United States          USA
# 5           5  United States          USA
# 6           6         Sweden          SWE
# 7           7         Sweden          SWE
# 8           8         Sweden          SWE
# 9           9         Sweden          SWE
#
#                                       Indicator Name     Indicator Code  \
# 0  Expenditure on primary as % of government expe...     SE.XPD.PRIM.ZS
# 1                       GDP per capita (current US$)     NY.GDP.PCAP.CD
# 2  Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# 3   Labor force with advanced education (% of total)     SL.TLF.ADVN.ZS
# 4  Pupil-teacher ratio in primary education (head...  SE.PRM.ENRL.TC.ZS
# ...
